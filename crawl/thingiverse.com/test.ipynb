# %%
from crawl_list import web_d,get_product_info_listpage

# %%
url = 'https://www.thingiverse.com/?page=1&sort=newest'
headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'Accept-Language': 'zh-CN,zh;q=0.9',
            'Cache-Control': 'max-age=0',
            'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36',
            'Connection': 'close'
            }

# %%
driver = web_d(headers)
driver = driver.get_driver()

# %%
data = get_product_info_listpage(url,driver)
driver.quit()
# Out:
# read data from: https://www.thingiverse.com/?page=1&sort=newest
# load url success
# bs4 success
# read html success

# %%
data
# Out:
#              username                                       userlink  \
# 0       Liberation404      https://www.thingiverse.com/Liberation404
# 1          GrnEyedDvl         https://www.thingiverse.com/GrnEyedDvl
# 2                None                                           None
# 3        OminousFyxen       https://www.thingiverse.com/OminousFyxen
# 4          jesuslayer         https://www.thingiverse.com/jesuslayer
# 5          GrnEyedDvl         https://www.thingiverse.com/GrnEyedDvl
# 6                None                                           None
# 7            makermcd           https://www.thingiverse.com/makermcd
# 8   3dprintmodelstore  https://www.thingiverse.com/3dprintmodelstore
# 9          Japhethson         https://www.thingiverse.com/Japhethson
# 10          Stebashka          https://www.thingiverse.com/Stebashka
# 11          Alanmas4K          https://www.thingiverse.com/Alanmas4K
# 12       QWILLIAMS316       https://www.thingiverse.com/QWILLIAMS316
# 13       OminousFyxen       https://www.thingiverse.com/OminousFyxen
# 14          Alanmas4K          https://www.thingiverse.com/Alanmas4K
# 15            Sagejoe            https://www.thingiverse.com/Sagejoe
# 16           Biotic3d           https://www.thingiverse.com/Biotic3d
# 17            Redrias            https://www.thingiverse.com/Redrias
# 18           Mikeru12           https://www.thingiverse.com/Mikeru12
# 19               None                                           None
# 20       goblinxqueen       https://www.thingiverse.com/goblinxqueen
# 21            Dinkus1            https://www.thingiverse.com/Dinkus1
# 22            Dinkus1            https://www.thingiverse.com/Dinkus1
#
#           itemlink                                          itemtitle  \
# 0   /thing:6717501                                            vtm d10
# 1   /thing:6717494                                  Bushing Generator
# 2             None                                      Advertisement
# 3   /thing:6717493  Adorable, Scalable Mix-and-Match Mushroom Deco...
# 4   /thing:6717492                       cup for hydroponic gardening
# 5   /thing:6717491                        Tip Out Tray - Customizable
# 6             None                                      Advertisement
# 7   /thing:6687248            Crunch Labs Disk Launcher extended tube
# 8   /thing:6715173  Dr Doom Mask - Marvel Doctor Doom Helmet Cospl...
# 9   /thing:6717465             M4 track with duckbill extenders 1:100
# 10  /thing:6717468                         Razer Cynosa Pro foot slim
# 11  /thing:6717467                              VW Cover Plug for aux
# 12  /thing:6717466                           Guitar Hero Guitar Mount
# 13  /thing:6717461  Cute and Cozy Mix-and-Match Mushroom Lamps (LE...
# 14  /thing:6717459                                    Volkswagen clip
# 15  /thing:6717453                        Moonlight canopy Pavo pico
# 16  /thing:6717435                              Articulated Crocodile
# 17  /thing:6717434                  Arrow Mount / Holder with Magnets
# 18  /thing:6717427                        Arkansas catfish key chain
# 19            None                                      Advertisement
# 20  /thing:6717420                              travelele, single bed
# 21  /thing:6716117                      Flexcut Rotating Tool Holder
# 22  /thing:6716121                                 Friendly Mr. Heart
#
#             itemid
# 0   /thing:6717501
# 1   /thing:6717494
# 2             None
# 3   /thing:6717493
# 4   /thing:6717492
# 5   /thing:6717491
# 6             None
# 7   /thing:6687248
# 8   /thing:6715173
# 9   /thing:6717465
# 10  /thing:6717468
# 11  /thing:6717467
# 12  /thing:6717466
# 13  /thing:6717461
# 14  /thing:6717459
# 15  /thing:6717453
# 16  /thing:6717435
# 17  /thing:6717434
# 18  /thing:6717427
# 19            None
# 20  /thing:6717420
# 21  /thing:6716117
# 22  /thing:6716121
