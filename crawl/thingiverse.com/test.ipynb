# %%
from task import read_channel,read_items
from core import web_d,download_files1
from fake_useragent import UserAgent

# %%
user_url = 'https://www.thingiverse.com/makerkingwoods15/designs'
headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'Accept-Language': 'zh-CN,zh;q=0.9',
            'Cache-Control': 'max-age=0',
            'User-Agent': UserAgent(),
            'Connection': 'close'
            }
web_att = web_d(headers=headers)
web_att.init_driver()
# Out:
# Bearer 56edfc79ecf25922b98202dd79a291aa
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       2 headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#       3             'Accept-Language': 'zh-CN,zh;q=0.9',
#       4             'Cache-Control': 'max-age=0',
#       5             'User-Agent': UserAgent(),
#       6             'Connection': 'close'
#       7             }
#       8 web_att = web_d(headers=headers)
# ----> 9 web_att.init_driver()
#
# File e:\workspace\python\mywork\MyWork\crawl\thingiverse.com\core.py:70, in web_d.init_driver(self, url)
#      68 self.driver = webdriver.Chrome(service=service,options=self.options)
#      69 self.driver.header_overrides={"Authorization":self.authorization}
# ---> 70 for request in self.driver.requests:
#      71     print(request.headers)
# ...

# %%
download_files1(web_att,'6687166')
# Out:
# Bearer 56edfc79ecf25922b98202dd79a291aa
# read data from: https://www.thingiverse.com/api/things/6687166/FilesDownloadCounterIncrease?t=1722857984205

# %%
web_att.read_data_from(user_url)
# Out:
# read data from: https://www.thingiverse.com/makerkingwoods15/designs
# <selenium.webdriver.chrome.webdriver.WebDriver (session="4bdb980e7ffed47997426d648dae6334")>

# %%
web_att.get_authorization()
# Out:
# read data from: https://cdn.thingiverse.com/site/js/app.bundle.js
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 web_att.get_authorization()
#
# File e:\workspace\python\mywork\MyWork\crawl\thingiverse.com\core.py:81, in web_d.get_authorization(self)
#      79 def get_authorization(self):
#      80     ddd = self.read_data_from("""https://cdn.thingiverse.com/site/js/app.bundle.js""")
# ---> 81     print(re.findall("""d=.*,f=""",re.findall("""86744.*;""",ddd.page_source)[0])[0])
#      82     authorization = re.findall("""d=.*,f=""",re.findall("""86744.*;""",ddd.page_source)[0])[0].split(',')[0].split('"')[1]
#      83     return(authorization)
#
# IndexError: list index out of range

# %%
ddd = web_att.read_data_from("""https://cdn.thingiverse.com/site/js/app.bundle.js""")
# Out:
# read data from: https://cdn.thingiverse.com/site/js/app.bundle.js

# %%
re.findall("""86744.*;""",ddd.page_source)
# Out:
# ['86744),o="".concat("prod"),i="".concat("https://www.thingiverse.com","/"),c="".concat("https://www.thingiverse.com/api"),s="".concat("https://cdn.thingiverse.com"),l="".concat("https://tv-zip.thingiverse.com"),u=("".concat("a1pf06e8fpp779q"),"".concat("lytu7wprnl9qd5n")),d="56edfc79ecf25922b98202dd79a291aa",f="scad",p=("".concat("https://reflector.makerbot.com"),"https://www.makerbot.com"),m=("".concat("https://cloudprint.makerbot.com"),"https://www.makerbot.com/3d-printers/materials-new-pla-colors/?utm_source=thingiverse&amp;utm_medium=organic&amp;utm_campaign=24-AMER-EDU-NewSketchColorsThingiverse&amp;utm_content=education-page"),h={IMAGES_URL:"https://cdn.thingiverse.com/site/assets",PRIVACY_POLICI_URL:"".concat(p,"/legal/privacy/"),TV_EDU_URL:"".concat(p,"/3d-printers/sketch-classroom/?utm_source=thingiverse&amp;utm_medium=organic&amp;utm_campaign=20edusketch"),DEFAULT_USER_AVATAR:"https://cdn.thingiverse.com/site/img/default/avatar/avatar_default_thumb_medium.jpg",TERMS_POLICI
# ...

# %%
import re
re.findall("""d=.*,f=""",re.findall("""r,a=n(86744),o.*;""",ddd.page_source)[0])[0].split(',')[0].split('"')[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import re
# ----> 2 re.findall("""d=.*,f=""",re.findall("""r,a=n(86744),o.*;""",ddd.page_source)[0])[0].split(',')[0].split('"')[1]
#
# IndexError: list index out of range

# %%
len(web_att.read_data_from("""https://cdn.thingiverse.com/site/js/app.bundle.js""").page_source)
# Out:
# read data from: https://cdn.thingiverse.com/site/js/app.bundle.js
# 151

# %%
web_att.get_authorization()
# Out:
# read data from: https://cdn.thingiverse.com/site/js/app.bundle.js
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 web_att.get_authorization()
#
# File e:\workspace\python\mywork\MyWork\crawl\thingiverse.com\core.py:81, in web_d.get_authorization(self)
#      79 def get_authorization(self):
#      80     return_value = self.read_data_from("""https://cdn.thingiverse.com/site/js/app.bundle.js""")
# ---> 81     authorization = re.findall("""d=.*,f=""",re.findall("""86744.*;""",return_value.page_source)[0])[0].split(',')[0].split('"')[1]
#      82     return(authorization)
#
# IndexError: list index out of range

# %%
import re

# %%
re.findall("""86744.*;""",ddd.page_source)[0]
# Out:
# '86744),o="".concat("prod"),i="".concat("https://www.thingiverse.com","/"),c="".concat("https://www.thingiverse.com/api"),s="".concat("https://cdn.thingiverse.com"),l="".concat("https://tv-zip.thingiverse.com"),u=("".concat("a1pf06e8fpp779q"),"".concat("lytu7wprnl9qd5n")),d="56edfc79ecf25922b98202dd79a291aa",f="scad",p=("".concat("https://reflector.makerbot.com"),"https://www.makerbot.com"),m=("".concat("https://cloudprint.makerbot.com"),"https://www.makerbot.com/3d-printers/materials-new-pla-colors/?utm_source=thingiverse&amp;utm_medium=organic&amp;utm_campaign=24-AMER-EDU-NewSketchColorsThingiverse&amp;utm_content=education-page"),h={IMAGES_URL:"https://cdn.thingiverse.com/site/assets",PRIVACY_POLICI_URL:"".concat(p,"/legal/privacy/"),TV_EDU_URL:"".concat(p,"/3d-printers/sketch-classroom/?utm_source=thingiverse&amp;utm_medium=organic&amp;utm_campaign=20edusketch"),DEFAULT_USER_AVATAR:"https://cdn.thingiverse.com/site/img/default/avatar/avatar_default_thumb_medium.jpg",TERMS_POLICI_
# ...

# %%
re.findall("""d=.*,f=""",re.findall("""86744.*;""",ddd.page_source)[0])[0].split(',')[0].split('"')[1]
# Out:
# '56edfc79ecf25922b98202dd79a291aa'

# %%
get_authorization(web_att.driver)
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_authorization(web_att.driver)
#
# File e:\workspace\python\mywork\MyWork\crawl\thingiverse.com\read_format.py:38, in get_authorization(driver)
#      37 def get_authorization(driver):
# ---> 38     return_value = driver.execute_async_script("""https://cdn.thingiverse.com/site/js/app.bundle.js""")
#      39     return(return_value)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:433, in WebDriver.execute_async_script(self, script, *args)
#     430 converted_args = list(args)
#     431 command = Command.W3C_EXECUTE_SCRIPT_ASYNC
# --> 433 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# ...

# %%
user_url = 'https://www.thingiverse.com/makerkingwoods15/designs'

read_channel(user_url)
# Out:
# read data from: https://www.thingiverse.com/makerkingwoods15/designs
# 1     6698570
# 2     6695203
# 3     6691347
# 4     6691331
# 5     6691236
# 6     6691241
# 7     6686114
# 8     6686052
# 9     6675947
# 10    6673530
# 11    6672650
# Name: itemId, dtype: object
# https://www.thingiverse.com/thing:6698570','https://www.thingiverse.com/thing:6695203','https://www.thingiverse.com/thing:6691347','https://www.thingiverse.com/thing:6691331','https://www.thingiverse.com/thing:6691236','https://www.thingiverse.com/thing:6691241','https://www.thingiverse.com/thing:6686114','https://www.thingiverse.com/thing:6686052','https://www.thingiverse.com/thing:6675947','https://www.thingiverse.com/thing:6673530','https://www.thingiverse.com/thing:6672650
#             userName                                      userLink  \
# 1   MakerKingWoods15  https://www.thingiverse.com/MakerKingWoods15
# 2   MakerKingWoods15  https://www.thingiverse.com/MakerKingWoods15
# ...

# %%
item_url = ['https://www.thingiverse.com/thing:6691347','https://www.thingiverse.com/thing:6691331','https://www.thingiverse.com/thing:6691236','https://www.thingiverse.com/thing:6691241','https://www.thingiverse.com/thing:6686114','https://www.thingiverse.com/thing:6686052','https://www.thingiverse.com/thing:6675947','https://www.thingiverse.com/thing:6673530','https://www.thingiverse.com/thing:6672650']

# %%
read_items(item_url)
# Out:
# read data from: https://www.thingiverse.com/thing:6691347
# 0    6691347
# Name: itemId, dtype: object
# Under the path: E:/workspace/python/mywork/download
# 0    Baseball Stand - 6691347.zip
# dtype: object is not exist
# wait 40

# %%
','.join([])
# Out:
# ''
